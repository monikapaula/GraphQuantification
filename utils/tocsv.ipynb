# %%
import json
import pandas as pd
from pathlib import Path
from utils.data_loader import DATA_ROOT

file_path = file_path = Path(DATA_ROOT) / "split_data" / "presidential_election" / "split_2" / "train.json"

with open(file_path, 'r') as f:
    data = json.load(f)

df = pd.DataFrame({
    'Id': data,
    'is_training': 1
})
df.to_csv('gephi_training_flag_split_2.csv', index=False)

print(f"Successfully processed {len(df)} training nodes. File saved as 'gephi_training_flag.csv'.")
# Out:
# Successfully processed 1341 training nodes. File saved as 'gephi_training_flag.csv'.
